# %% [markdown]
# ### Installing modules

# %%
# ! pip install pandas scikit-learn
! echo "Installing Deps"
! pip install -r requirements.txt
! echo "Installed Deps"
! pip freeze > requirements.txt
# Out:
# "Installing Deps"
# Requirement already satisfied: asttokens==2.4.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: colorama==0.4.6 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: comm==0.2.2 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 3)) (0.2.2)
# Requirement already satisfied: debugpy==1.8.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 4)) (1.8.1)
# Requirement already satisfied: decorator==5.1.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 5)) (5.1.1)
# Requirement already satisfied: executing==2.0.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 6)) (2.0.1)
# Requirement already satisfied: ipykernel==6.29.4 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 7)) (6.29.4)
# Requirement already satisfied: ipython==8.25.0 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 8)) (8.25.0)
# Requirement already satisfied: jedi==0.19.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 9)) (0.19.1)
# Requirement already satisfied: joblib==1.4.2 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 10)) (1.4.2)
# Requirement already satisfied: jupyter_client==8.6.2 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 11)) (8.6.2)
# Requirement already satisfied: jupyter_core==5.7.2 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 12)) (5.7.2)
# Requirement already satisfied: matplotlib-inline==0.1.7 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 13)) (0.1.7)
# Requirement already satisfied: nest-asyncio==1.6.0 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 14)) (1.6.0)
# Requirement already satisfied: numpy==1.26.4 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 15)) (1.26.4)
# Requirement already satisfied: packaging==24.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 16)) (24.1)
# Requirement already satisfied: pandas==2.2.2 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 17)) (2.2.2)
# Requirement already satisfied: parso==0.8.4 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 18)) (0.8.4)
# Requirement already satisfied: platformdirs==4.2.2 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 19)) (4.2.2)
# Requirement already satisfied: prompt_toolkit==3.0.47 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 20)) (3.0.47)
# Requirement already satisfied: psutil==5.9.8 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 21)) (5.9.8)
# Requirement already satisfied: pure-eval==0.2.2 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 22)) (0.2.2)
# Requirement already satisfied: Pygments==2.18.0 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 23)) (2.18.0)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 24)) (2.9.0.post0)
# Requirement already satisfied: pytz==2024.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 25)) (2024.1)
# Requirement already satisfied: pywin32==306 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 26)) (306)
# Requirement already satisfied: pyzmq==26.0.3 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 27)) (26.0.3)
# Requirement already satisfied: scikit-learn==1.5.0 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 28)) (1.5.0)
# Requirement already satisfied: scipy==1.13.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 29)) (1.13.1)
# Requirement already satisfied: six==1.16.0 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 30)) (1.16.0)
# Requirement already satisfied: stack-data==0.6.3 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 31)) (0.6.3)
# Requirement already satisfied: threadpoolctl==3.5.0 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 32)) (3.5.0)
# Requirement already satisfied: tornado==6.4.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 33)) (6.4.1)
# Requirement already satisfied: traitlets==5.14.3 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 34)) (5.14.3)
# Requirement already satisfied: tzdata==2024.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 35)) (2024.1)
# Requirement already satisfied: wcwidth==0.2.13 in c:\users\pritamkundu\documents\projects\hr-chatbot\src\lib\site-packages (from -r requirements.txt (line 36)) (0.2.13)
# "Installed Deps"

# %% [markdown]
# ### Importing modules

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
from numpy import ndarray

# %% [markdown]
# ### Load the dataset

# %%
data = pd.read_csv('knowledge_base.csv')
data
# Out:
#                                                 Query  \
# 0                          What are the office hours?
# 1                How do I find the employee handbook?
# 2              How many vacation days do I have left?
# 3                 How do I apply for maternity leave?
# 4                            When is the next payday?
# 5   How do I change my bank account for salary dep...
# 6          What should I do if I get injured at work?
# 7      What are the COVID-19 protocols in the office?
# 8           Are there any upcoming training sessions?
# 9   How do I enroll in a professional development ...
# 10              How do I report workplace harassment?
# 11        What is the process for filing a grievance?
# 12             How do I access my performance review?
# 13  What is the process for setting goals for the ...
# 14  How do I nominate someone for an employee reco...
# 15  What are the criteria for receiving a performa...
#
#                                              Response
# 0   Our office hours are from 9 AM to 6 PM, Monday...
# 1   You can find the employee handbook on the comp...
# 2   You can check your remaining vacation days on ...
# 3   To apply for maternity leave, please fill out ...
# 4   The next payday is on the last working day of ...
# 5   To change your bank account details, please up...
# 6   If you get injured at work, report the injury ...
# 7   Please follow the COVID-19 protocols outlined ...
# 8   You can find the schedule for upcoming trainin...
# 9   To enroll in a professional development course...
# 10  To report workplace harassment, please contact...
# 11  To file a grievance, please complete the griev...
# 12  You can access your performance review on the ...
# 13  To set goals for the new quarter, use the goal...
# 14  To nominate someone for an employee recognitio...
# 15  The criteria for receiving a performance bonus...

# %% [markdown]
# ### Extract the queries and responses

# %%
queries, responses = data['Query'], data['Response']

# %% [markdown]
# ### Create models

# %%
tfIdModel = TfidfVectorizer()
multinominalModel = MultinomialNB()

# %% [markdown]
# ### Create final model by pipelining

# %%
chatbotModel = make_pipeline(tfIdModel, multinominalModel)

# %% [markdown]
# ### Model training

# %%
chatbotModel.fit(queries, responses)
# Out:
# Pipeline(steps=[('tfidfvectorizer', TfidfVectorizer()),
#                 ('multinomialnb', MultinomialNB())])

# %% [markdown]
# ### Testing

# %%
def get_response(query):
    response: ndarray = chatbotModel.predict([query])
    return response

# %% [markdown]
# ### Take input

# %%
print(get_response("hours"))
