# %% [markdown]
# ### Installing modules

# %%
# ! pip install pandas scikit-learn
! echo "Installing Deps"
! pip install -r requirements.txt
! echo "Installed Deps"
! pip freeze > requirements.txt
# Out:
# "Installing Deps"
# Requirement already satisfied: asttokens==2.4.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: click==8.1.7 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 2)) (8.1.7)
# Requirement already satisfied: colorama==0.4.6 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 3)) (0.4.6)
# Requirement already satisfied: comm==0.2.2 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 4)) (0.2.2)
# Requirement already satisfied: debugpy==1.8.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 5)) (1.8.1)
# Requirement already satisfied: decorator==5.1.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: executing==2.0.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 7)) (2.0.1)
# Requirement already satisfied: filelock==3.13.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 8)) (3.13.1)
# Requirement already satisfied: fsspec==2024.2.0 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 9)) (2024.2.0)
# Requirement already satisfied: intel-openmp==2021.4.0 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 10)) (2021.4.0)
# Requirement already satisfied: ipykernel==6.29.4 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 11)) (6.29.4)
# Requirement already satisfied: ipython==8.25.0 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 12)) (8.25.0)
# Requirement already satisfied: jedi==0.19.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 13)) (0.19.1)
# Requirement already satisfied: Jinja2==3.1.3 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 14)) (3.1.3)
# Requirement already satisfied: joblib==1.4.2 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 15)) (1.4.2)
# Requirement already satisfied: jupyter_client==8.6.2 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 16)) (8.6.2)
# Requirement already satisfied: jupyter_core==5.7.2 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 17)) (5.7.2)
# Requirement already satisfied: MarkupSafe==2.1.5 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 18)) (2.1.5)
# Requirement already satisfied: matplotlib-inline==0.1.7 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 19)) (0.1.7)
# Requirement already satisfied: mkl==2021.4.0 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 20)) (2021.4.0)
# Requirement already satisfied: mpmath==1.3.0 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 21)) (1.3.0)
# Requirement already satisfied: nest-asyncio==1.6.0 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 22)) (1.6.0)
# Requirement already satisfied: networkx==3.2.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 23)) (3.2.1)
# Requirement already satisfied: nltk==3.8.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 24)) (3.8.1)
# Requirement already satisfied: numpy==1.26.3 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 25)) (1.26.3)
# Requirement already satisfied: packaging==24.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 26)) (24.1)
# Requirement already satisfied: pandas==2.2.2 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 27)) (2.2.2)
# Requirement already satisfied: parso==0.8.4 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 28)) (0.8.4)
# Requirement already satisfied: pillow==10.2.0 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 29)) (10.2.0)
# Requirement already satisfied: platformdirs==4.2.2 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 30)) (4.2.2)
# Requirement already satisfied: prompt_toolkit==3.0.47 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 31)) (3.0.47)
# Requirement already satisfied: psutil==6.0.0 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 32)) (6.0.0)
# Requirement already satisfied: pure-eval==0.2.2 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 33)) (0.2.2)
# Requirement already satisfied: Pygments==2.18.0 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 34)) (2.18.0)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 35)) (2.9.0.post0)
# Requirement already satisfied: pytz==2024.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 36)) (2024.1)
# Requirement already satisfied: pywin32==306 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 37)) (306)
# Requirement already satisfied: pyzmq==26.0.3 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 38)) (26.0.3)
# Requirement already satisfied: regex==2024.5.15 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 39)) (2024.5.15)
# Requirement already satisfied: scikit-learn==1.5.0 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 40)) (1.5.0)
# Requirement already satisfied: scipy==1.13.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 41)) (1.13.1)
# Requirement already satisfied: six==1.16.0 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 42)) (1.16.0)
# Requirement already satisfied: stack-data==0.6.3 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 43)) (0.6.3)
# Requirement already satisfied: sympy==1.12 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 44)) (1.12)
# Requirement already satisfied: tbb==2021.11.0 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 45)) (2021.11.0)
# Requirement already satisfied: threadpoolctl==3.5.0 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 46)) (3.5.0)
# Requirement already satisfied: torch==2.3.1+cpu in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 47)) (2.3.1+cpu)
# Requirement already satisfied: torchaudio==2.3.1+cpu in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 48)) (2.3.1+cpu)
# Requirement already satisfied: torchvision==0.18.1+cpu in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 49)) (0.18.1+cpu)
# Requirement already satisfied: tornado==6.4.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 50)) (6.4.1)
# Requirement already satisfied: tqdm==4.66.4 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 51)) (4.66.4)
# Requirement already satisfied: traitlets==5.14.3 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 52)) (5.14.3)
# Requirement already satisfied: typing_extensions==4.9.0 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 53)) (4.9.0)
# Requirement already satisfied: tzdata==2024.1 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 54)) (2024.1)
# Requirement already satisfied: wcwidth==0.2.13 in c:\users\pritamkundu\documents\projects\hr-chatbot\lib\site-packages (from -r requirements.txt (line 55)) (0.2.13)
# "Installed Deps"

# %% [markdown]
# ### Importing modules

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
from numpy import ndarray
import re

# %% [markdown]
# ### Load the dataset

# %%
data = pd.read_csv('knowledge_base.csv')
data
# Out:
#                                                 Query  \
# 0                          What are the office hours?
# 1                How do I find the employee handbook?
# 2              How many vacation days do I have left?
# 3                 How do I apply for maternity leave?
# 4                            When is the next payday?
# 5   How do I change my bank account for salary dep...
# 6          What should I do if I get injured at work?
# 7      What are the COVID-19 protocols in the office?
# 8           Are there any upcoming training sessions?
# 9   How do I enroll in a professional development ...
# 10              How do I report workplace harassment?
# 11        What is the process for filing a grievance?
# 12             How do I access my performance review?
# 13  What is the process for setting goals for the ...
# 14  How do I nominate someone for an employee reco...
# 15  What are the criteria for receiving a performa...
# 16  What are the responsibilities of employees or ...
# 17  Who should they notify for remote work policy,...
# 18  What happens if someone doesn't comply with th...
# 19        What equipment is required for remote work?
# 20                  What about internet connectivity?
# 21  What are the requirements for certification to...
# 22  Who pays for the certification or exam fees in...
# 23         What are the conditions for reimbursement?
# 24                  When will the fees be reimbursed?
# 25  What happens if I fail the exam on my first at...
# 26                  And if I fail the second attempt?
# 27         I have a question about salary increments.
#
#                                              Response
# 0   Our office hours are from 9 AM to 6 PM, Monday...
# 1   You can find the employee handbook on the comp...
# 2   You can check your remaining vacation days on ...
# 3   To apply for maternity leave, please fill out ...
# 4   The next payday is on the last working day of ...
# 5   To change your bank account details, please up...
# 6   If you get injured at work, report the injury ...
# 7   Please follow the COVID-19 protocols outlined ...
# 8   You can find the schedule for upcoming trainin...
# 9   To enroll in a professional development course...
# 10  To report workplace harassment, please contact...
# 11  To file a grievance, please complete the griev...
# 12  You can access your performance review on the ...
# 13  To set goals for the new quarter, use the goal...
# 14  To nominate someone for an employee recognitio...
# 15  The criteria for receiving a performance bonus...
# 16  Employees or contractors planning to work from...
# 17  They need to send an email to both HR Support ...
# 18  Pursuit Software reserves the right to take ap...
# 19  A secure, up-to-date computer or laptop that m...
# 20  Primary Internate connection should be your ma...
# 21  For certification to be eligible for reimburse...
# 22  The employee must initially pay for the certif...
# 23  To be eligible for reimbursement:1.The employe...
# 24  The fees will be reimbursed 90 days after the ...
# 25  If you fail the exam on your first attempt, yo...
# 26  If you fail the second attempt, there will be ...
# 27  I understand that salary increments are an imp...

# %% [markdown]
# ### Extract the queries and responses

# %%
queries, responses = data['Query'], data['Response']

# %% [markdown]
# ### Create models

# %%
tfIdModel = TfidfVectorizer()
multinominalModel = MultinomialNB()

# %% [markdown]
# ### Create final model by pipelining

# %%
chatbotModel = make_pipeline(tfIdModel, multinominalModel)

# %% [markdown]
# ### Model training

# %%
chatbotModel.fit(queries, responses)
# Out:
# Pipeline(steps=[('tfidfvectorizer', TfidfVectorizer()),
#                 ('multinomialnb', MultinomialNB())])

# %% [markdown]
# ### Testing

# %%
def get_response(query: str):
    return chatbotModel.predict([query])

# %% [markdown]
# ### Take input

# %%
print(get_response("When the next payday?"))
# Out:
# ['The next payday is on the last working day of the month.']
